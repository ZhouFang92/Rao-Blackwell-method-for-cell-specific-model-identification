# %%
import numpy as np
import pandas as pd
import time

import scipy.io as sio
import matplotlib.pyplot as plt
from scipy.stats import poisson

file_name = 'data45.mat'
real_data = sio.loadmat(file_name)
cell_index = 78
mRNA_trjectatory = real_data['cellTrajectory'][0,cell_index][0,0][0]/73 # 73 is the scaling factor
Observation_times_list= list(range(2, len(mRNA_trjectatory)*2, 2))
Y_list = [np.array(element) for element in mRNA_trjectatory[1:]]

plt.step(Observation_times_list, Y_list, where='post')
